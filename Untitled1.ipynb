# %%
import numpy as np
import pandas as pd

# %%
co=pd.read_csv('COVID19_line_list_data.csv')

# %%
co
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# 5        6              NaN      1/21/2020         NaN
# 6        7              NaN      1/21/2020         NaN
# 7        8              NaN      1/21/2020         NaN
# 8        9              NaN      1/21/2020         NaN
# 9       10              NaN      1/21/2020         NaN
# 10      11              NaN      1/21/2020         NaN
# 11      12              NaN      1/21/2020         NaN
# 12      13              NaN      1/21/2020         NaN
# 13      14              NaN      1/21/2020         NaN
# 14      15              NaN      1/22/2020         NaN
# 15      16              NaN      1/22/2020         NaN
# ...

# %%
co=co.drop(columns=['id'])
co=co.drop(columns=(['case_in_country',"symptom","recovered","death","If_onset_approximated","source",'Unnamed: 3',"link","Unnamed: 21","Unnamed: 22","Unnamed: 23","Unnamed: 24","Unnamed: 25","Unnamed: 26"
                    ]))

# %%
co.head()
# Out:
#   reporting date                                            summary  \
# 0      1/20/2020  First confirmed imported COVID-19 pneumonia pa...
# 1      1/20/2020  First confirmed imported COVID-19 pneumonia pa...
# 2      1/21/2020  First confirmed imported cases in Zhejiang: pa...
# 3      1/21/2020  new confirmed imported COVID-19 pneumonia in T...
# 4      1/21/2020  new confirmed imported COVID-19 pneumonia in T...
#
#               location country  gender   age symptom_onset hosp_visit_date  \
# 0  Shenzhen, Guangdong   China    male  66.0      01/03/20        01/11/20
# 1             Shanghai   China  female  56.0     1/15/2020       1/15/2020
# 2             Zhejiang   China    male  46.0      01/04/20       1/17/2020
# 3              Tianjin   China  female  60.0           NaN       1/19/2020
# 4              Tianjin   China    male  58.0           NaN       1/14/2020
#
#   exposure_start exposure_end  visiting Wuhan  from Wuhan
# ...

# %%
from sklearn.De
