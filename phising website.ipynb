# %%
import pandas as pd
from scipy.io import arff
from io import StringIO
import requests as rt

# %%
dt=rt.request('get','https://archive.ics.uci.edu/ml/machine-learning-databases/00327/.old.arff')

# %%
dt=pd.DataFrame(arff.loadarff(StringIO(dt.text))[0])

# %%
dt.shape
# Out:
# (2456, 31)

# %%
dt.dtypes
# Out:
# having_IP_Address              object
# URL_Length                     object
# Shortining_Service             object
# having_At_Symbol               object
# double_slash_redirecting       object
# Prefix_Suffix                  object
# having_Sub_Domain              object
# SSLfinal_State                 object
# Domain_registeration_length    object
# Favicon                        object
# port                           object
# HTTPS_token                    object
# Request_URL                    object
# URL_of_Anchor                  object
# Links_in_tags                  object
# SFH                            object
# Submitting_to_email            object
# Abnormal_URL                   object
# Redirect                       object
# on_mouseover                   object
# RightClick                     object
# popUpWidnow                    object
# Iframe                         object
# age_of_domain                  object
# DNSRecord                      object
# web_traffic                    object
# Page_Rank                      object
# Google_Index                   object
# Links_pointing_to_page         object
# Statistical_report             object
# Result                         object
# dtype: object

# %%
dt.head(10)
# Out:
#   having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 0              b'1'       b'1'               b'0'             b'0'
# 1              b'0'       b'1'               b'0'             b'0'
# 2              b'0'       b'0'               b'0'             b'0'
# 3              b'0'       b'0'               b'0'             b'0'
# 4              b'0'       b'0'               b'1'             b'0'
# 5              b'1'       b'0'               b'1'             b'0'
# 6              b'0'      b'-1'               b'0'             b'0'
# 7              b'0'      b'-1'               b'0'             b'0'
# 8              b'0'       b'0'               b'0'             b'0'
# 9              b'0'       b'0'               b'0'             b'0'
#
#   double_slash_redirecting Prefix_Suffix having_Sub_Domain SSLfinal_State  \
# 0                     b'1'         b'-1'             b'-1'          b'-1'
# 1                     b'0'         b'-1'              b'0'           b'1'
# 2                     b'0'         b'-1'             b'-1'          b'-1'
# 3                     b'0'         b'-1'             b'-1'          b'-1'
# 4                     b'0'         b'-1'              b'1'           b'1'
# 5                     b'1'          b'0'              b'1'           b'1'
# 6                     b'0'         b'-1'             b'-1'           b'1'
# 7                     b'0'          b'1'              b'1'           b'1'
# 8                     b'0'          b'0'             b'-1'           b'1'
# 9                     b'0'          b'0'              b'0'           b'0'
#
#   Domain_registeration_length Favicon  ...   popUpWidnow Iframe age_of_domain  \
# 0                        b'0'    b'0'  ...          b'0'   b'0'         b'-1'
# 1                        b'0'    b'0'  ...          b'0'   b'0'         b'-1'
# 2                        b'0'    b'0'  ...          b'0'   b'0'          b'0'
# 3                        b'1'    b'0'  ...          b'0'   b'0'         b'-1'
# 4                        b'0'    b'0'  ...          b'1'   b'0'         b'-1'
# 5                        b'0'    b'0'  ...          b'0'   b'0'          b'0'
# 6                       b'-1'    b'1'  ...          b'1'   b'1'          b'1'
# 7                       b'-1'    b'0'  ...          b'0'   b'0'          b'1'
# 8                       b'-1'    b'0'  ...          b'0'   b'0'          b'1'
# 9                        b'1'    b'0'  ...          b'0'   b'0'          b'0'
#
#   DNSRecord web_traffic Page_Rank Google_Index Links_pointing_to_page  \
# 0      b'1'       b'-1'     b'-1'         b'0'                   b'1'
# 1      b'1'        b'0'     b'-1'         b'0'                   b'1'
# 2      b'1'        b'1'     b'-1'         b'0'                   b'0'
# 3      b'1'        b'1'     b'-1'         b'0'                  b'-1'
# 4      b'1'        b'0'     b'-1'         b'0'                   b'1'
# 5      b'0'        b'1'      b'0'         b'0'                  b'-1'
# 6      b'1'        b'1'      b'1'         b'0'                   b'0'
# 7      b'0'       b'-1'     b'-1'         b'0'                  b'-1'
# 8      b'0'        b'1'      b'0'         b'0'                   b'0'
# 9      b'1'        b'1'     b'-1'         b'0'                   b'1'
#
#   Statistical_report Result
# 0               b'1'   b'1'
# 1               b'0'   b'1'
# 2               b'1'   b'1'
# 3               b'0'   b'1'
# 4               b'0'  b'-1'
# 5               b'1'  b'-1'
# 6               b'1'  b'-1'
# 7               b'1'  b'-1'
# 8               b'1'  b'-1'
# 9               b'1'   b'1'
#
# [10 rows x 31 columns]

# %%
dt.tail(20)
# Out:
#      having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 2436              b'0'      b'-1'               b'0'             b'0'
# 2437              b'1'      b'-1'               b'1'             b'0'
# 2438              b'0'       b'1'               b'0'             b'1'
# 2439              b'0'      b'-1'               b'0'             b'0'
# 2440              b'1'      b'-1'               b'1'             b'0'
# 2441              b'0'      b'-1'               b'0'             b'0'
# 2442              b'0'      b'-1'               b'0'             b'0'
# 2443              b'0'      b'-1'               b'0'             b'0'
# 2444              b'0'       b'1'               b'0'             b'0'
# 2445              b'0'      b'-1'               b'0'             b'0'
# 2446              b'1'      b'-1'               b'1'             b'0'
# 2447              b'0'      b'-1'               b'0'             b'0'
# 2448              b'0'      b'-1'               b'0'             b'0'
# 2449              b'0'      b'-1'               b'0'             b'0'
# 2450              b'0'      b'-1'               b'0'             b'0'
# 2451              b'0'      b'-1'               b'0'             b'0'
# 2452              b'0'      b'-1'               b'0'             b'1'
# 2453              b'0'      b'-1'               b'0'             b'0'
# 2454              b'0'      b'-1'               b'0'             b'0'
# 2455              b'0'      b'-1'               b'0'             b'0'
#
#      double_slash_redirecting Prefix_Suffix having_Sub_Domain SSLfinal_State  \
# 2436                     b'0'          b'1'             b'-1'           b'1'
# 2437                     b'1'         b'-1'              b'0'          b'-1'
# 2438                     b'0'          b'0'             b'-1'           b'1'
# 2439                     b'0'          b'0'             b'-1'          b'-1'
# 2440                     b'1'         b'-1'              b'0'           b'0'
# 2441                     b'0'         b'-1'             b'-1'           b'1'
# 2442                     b'0'          b'0'             b'-1'          b'-1'
# 2443                     b'0'         b'-1'              b'0'           b'0'
# 2444                     b'0'          b'1'              b'1'           b'1'
# 2445                     b'0'         b'-1'              b'1'           b'1'
# 2446                     b'1'          b'0'             b'-1'           b'1'
# 2447                     b'0'          b'0'              b'0'           b'0'
# 2448                     b'0'          b'0'              b'0'           b'1'
# 2449                     b'0'         b'-1'              b'0'           b'0'
# 2450                     b'0'         b'-1'             b'-1'          b'-1'
# 2451                     b'0'          b'0'              b'0'          b'-1'
# 2452                     b'0'          b'0'              b'0'           b'0'
# 2453                     b'0'          b'0'              b'0'           b'1'
# 2454                     b'0'          b'0'             b'-1'          b'-1'
# 2455                     b'0'          b'0'              b'0'           b'1'
#
#      Domain_registeration_length Favicon  ...   popUpWidnow Iframe  \
# 2436                       b'-1'    b'1'  ...          b'1'   b'1'
# 2437                        b'0'    b'1'  ...          b'1'   b'1'
# 2438                       b'-1'    b'0'  ...          b'0'   b'0'
# 2439                        b'1'    b'0'  ...          b'0'   b'0'
# 2440                        b'1'    b'1'  ...          b'1'   b'1'
# 2441                        b'1'    b'0'  ...          b'0'   b'0'
# 2442                        b'1'    b'0'  ...          b'0'   b'0'
# 2443                       b'-1'    b'1'  ...          b'1'   b'1'
# 2444                       b'-1'    b'0'  ...          b'0'   b'0'
# 2445                        b'1'    b'0'  ...          b'0'   b'0'
# 2446                        b'0'    b'0'  ...          b'0'   b'0'
# 2447                        b'1'    b'0'  ...          b'0'   b'0'
# 2448                        b'1'    b'0'  ...          b'0'   b'0'
# 2449                        b'1'    b'1'  ...          b'1'   b'1'
# 2450                        b'0'    b'0'  ...          b'0'   b'0'
# 2451                        b'1'    b'0'  ...          b'0'   b'0'
# 2452                        b'1'    b'0'  ...          b'0'   b'0'
# 2453                        b'0'    b'0'  ...          b'0'   b'0'
# 2454                        b'1'    b'0'  ...          b'0'   b'0'
# 2455                        b'0'    b'0'  ...          b'0'   b'0'
#
#      age_of_domain DNSRecord web_traffic Page_Rank Google_Index  \
# 2436          b'1'      b'1'        b'1'     b'-1'         b'0'
# 2437          b'1'      b'1'       b'-1'     b'-1'         b'0'
# 2438          b'1'      b'0'        b'1'      b'1'         b'0'
# 2439          b'1'      b'0'       b'-1'     b'-1'         b'0'
# 2440          b'1'      b'1'        b'0'     b'-1'         b'0'
# 2441         b'-1'      b'0'        b'0'     b'-1'         b'0'
# 2442         b'-1'      b'1'        b'1'     b'-1'         b'0'
# 2443          b'0'      b'1'        b'1'     b'-1'         b'0'
# 2444          b'1'      b'1'       b'-1'     b'-1'         b'0'
# 2445          b'1'      b'0'        b'1'      b'1'         b'1'
# 2446          b'1'      b'1'        b'1'     b'-1'         b'0'
# 2447          b'0'      b'1'       b'-1'     b'-1'         b'0'
# 2448         b'-1'      b'0'       b'-1'     b'-1'         b'0'
# 2449          b'1'      b'1'        b'1'     b'-1'         b'1'
# 2450         b'-1'      b'0'        b'0'     b'-1'         b'1'
# 2451         b'-1'      b'0'        b'1'      b'0'         b'0'
# 2452          b'0'      b'1'       b'-1'      b'0'         b'0'
# 2453         b'-1'      b'0'        b'1'      b'0'         b'0'
# 2454          b'1'      b'0'       b'-1'     b'-1'         b'0'
# 2455         b'-1'      b'0'        b'1'      b'1'         b'0'
#
#      Links_pointing_to_page Statistical_report Result
# 2436                   b'1'               b'1'  b'-1'
# 2437                   b'1'               b'1'   b'1'
# 2438                   b'0'               b'0'  b'-1'
# 2439                   b'0'               b'0'   b'1'
# 2440                   b'1'               b'1'   b'1'
# 2441                   b'0'               b'0'   b'1'
# 2442                   b'1'               b'0'   b'1'
# 2443                   b'1'               b'1'   b'1'
# 2444                   b'1'               b'0'  b'-1'
# 2445                   b'0'               b'0'  b'-1'
# 2446                   b'1'               b'0'  b'-1'
# 2447                   b'1'               b'0'   b'1'
# 2448                   b'0'               b'0'  b'-1'
# 2449                   b'1'               b'1'   b'1'
# 2450                   b'0'               b'0'   b'1'
# 2451                   b'0'               b'0'   b'1'
# 2452                   b'1'               b'0'   b'1'
# 2453                   b'0'               b'0'  b'-1'
# 2454                   b'0'               b'0'   b'1'
# 2455                   b'0'               b'0'  b'-1'
#
# [20 rows x 31 columns]

# %%
dt.head
# Out:
# <bound method NDFrame.head of      having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 0                 b'1'       b'1'               b'0'             b'0'
# 1                 b'0'       b'1'               b'0'             b'0'
# 2                 b'0'       b'0'               b'0'             b'0'
# 3                 b'0'       b'0'               b'0'             b'0'
# 4                 b'0'       b'0'               b'1'             b'0'
# 5                 b'1'       b'0'               b'1'             b'0'
# 6                 b'0'      b'-1'               b'0'             b'0'
# 7                 b'0'      b'-1'               b'0'             b'0'
# 8                 b'0'       b'0'               b'0'             b'0'
# 9                 b'0'       b'0'               b'0'             b'0'
# 10                b'0'       b'0'               b'0'             b'0'
# 11                b'0'       b'0'               b'0'             b'0'
# 12                b'0'       b'0'               b'0'             b'0'
# 13                b'0'       b'1'               b'0'             b'0'
# 14                b'0'      b'-1'               b'0'             b'0'
# 15                b'0'      b'-1'               b'0'             b'0'
# 16                b'1'      b'-1'               b'1'             b'0'
# 17                b'0'      b'-1'               b'0'             b'0'
# 18                b'0'      b'-1'               b'0'             b'0'
# 19                b'0'      b'-1'               b'0'             b'1'
# 20                b'0'       b'1'               b'0'             b'0'
# 21                b'1'       b'1'               b'1'             b'0'
# 22                b'0'      b'-1'               b'0'             b'0'
# 23                b'0'      b'-1'               b'0'             b'0'
# 24                b'0'      b'-1'               b'0'             b'0'
# 25                b'0'      b'-1'               b'0'             b'0'
# 26                b'0'       b'1'               b'0'             b'0'
# 27                b'1'      b'-1'               b'1'             b'0'
# 28                b'0'      b'-1'               b'0'             b'0'
# 29                b'0'      b'-1'               b'0'             b'0'
# ...                ...        ...                ...              ...
# 2426              b'1'       b'1'               b'1'             b'0'
# 2427              b'0'      b'-1'               b'0'             b'0'
# 2428              b'0'      b'-1'               b'0'             b'0'
# 2429              b'0'      b'-1'               b'0'             b'0'
# 2430              b'0'      b'-1'               b'0'             b'0'
# 2431              b'0'      b'-1'               b'0'             b'0'
# 2432              b'0'      b'-1'               b'0'             b'0'
# 2433              b'0'      b'-1'               b'0'             b'0'
# 2434              b'0'      b'-1'               b'0'             b'0'
# 2435              b'0'       b'1'               b'0'             b'0'
# 2436              b'0'      b'-1'               b'0'             b'0'
# 2437              b'1'      b'-1'               b'1'             b'0'
# 2438              b'0'       b'1'               b'0'             b'1'
# 2439              b'0'      b'-1'               b'0'             b'0'
# 2440              b'1'      b'-1'               b'1'             b'0'
# 2441              b'0'      b'-1'               b'0'             b'0'
# 2442              b'0'      b'-1'               b'0'             b'0'
# 2443              b'0'      b'-1'               b'0'             b'0'
# 2444              b'0'       b'1'               b'0'             b'0'
# 2445              b'0'      b'-1'               b'0'             b'0'
# 2446              b'1'      b'-1'               b'1'             b'0'
# 2447              b'0'      b'-1'               b'0'             b'0'
# 2448              b'0'      b'-1'               b'0'             b'0'
# 2449              b'0'      b'-1'               b'0'             b'0'
# 2450              b'0'      b'-1'               b'0'             b'0'
# 2451              b'0'      b'-1'               b'0'             b'0'
# 2452              b'0'      b'-1'               b'0'             b'1'
# 2453              b'0'      b'-1'               b'0'             b'0'
# 2454              b'0'      b'-1'               b'0'             b'0'
# 2455              b'0'      b'-1'               b'0'             b'0'
#
#      double_slash_redirecting Prefix_Suffix having_Sub_Domain SSLfinal_State  \
# 0                        b'1'         b'-1'             b'-1'          b'-1'
# 1                        b'0'         b'-1'              b'0'           b'1'
# 2                        b'0'         b'-1'             b'-1'          b'-1'
# 3                        b'0'         b'-1'             b'-1'          b'-1'
# 4                        b'0'         b'-1'              b'1'           b'1'
# 5                        b'1'          b'0'              b'1'           b'1'
# 6                        b'0'         b'-1'             b'-1'           b'1'
# 7                        b'0'          b'1'              b'1'           b'1'
# 8                        b'0'          b'0'             b'-1'           b'1'
# 9                        b'0'          b'0'              b'0'           b'0'
# 10                       b'0'         b'-1'             b'-1'          b'-1'
# 11                       b'0'          b'0'             b'-1'           b'1'
# 12                       b'0'          b'0'             b'-1'          b'-1'
# 13                       b'0'          b'1'             b'-1'           b'1'
# 14                       b'0'          b'0'              b'0'          b'-1'
# 15                       b'0'          b'1'              b'1'           b'1'
# 16                       b'1'          b'0'              b'1'           b'1'
# 17                       b'0'         b'-1'             b'-1'          b'-1'
# 18                       b'0'         b'-1'              b'0'           b'0'
# 19                       b'0'         b'-1'              b'0'          b'-1'
# 20                       b'0'          b'0'              b'0'           b'1'
# 21                       b'1'          b'1'             b'-1'           b'1'
# 22                       b'0'         b'-1'             b'-1'          b'-1'
# 23                       b'0'         b'-1'             b'-1'           b'1'
# 24                       b'0'          b'0'              b'1'           b'1'
# 25                       b'0'         b'-1'              b'1'           b'1'
# 26                       b'0'         b'-1'              b'1'           b'1'
# 27                       b'1'          b'1'             b'-1'           b'1'
# 28                       b'0'         b'-1'              b'1'          b'-1'
# 29                       b'0'         b'-1'              b'0'          b'-1'
# ...                       ...           ...               ...            ...
# 2426                     b'1'          b'0'             b'-1'          b'-1'
# 2427                     b'0'          b'0'              b'1'           b'1'
# 2428                     b'0'          b'0'             b'-1'           b'1'
# 2429                     b'0'          b'0'              b'1'           b'1'
# 2430                     b'0'         b'-1'              b'0'          b'-1'
# 2431                     b'0'         b'-1'              b'0'          b'-1'
# 2432                     b'0'          b'0'              b'1'           b'1'
# 2433                     b'0'          b'0'             b'-1'           b'1'
# 2434                     b'0'         b'-1'              b'0'           b'0'
# 2435                     b'0'          b'0'             b'-1'           b'1'
# 2436                     b'0'          b'1'             b'-1'           b'1'
# 2437                     b'1'         b'-1'              b'0'          b'-1'
# 2438                     b'0'          b'0'             b'-1'           b'1'
# 2439                     b'0'          b'0'             b'-1'          b'-1'
# 2440                     b'1'         b'-1'              b'0'           b'0'
# 2441                     b'0'         b'-1'             b'-1'           b'1'
# 2442                     b'0'          b'0'             b'-1'          b'-1'
# 2443                     b'0'         b'-1'              b'0'           b'0'
# 2444                     b'0'          b'1'              b'1'           b'1'
# 2445                     b'0'         b'-1'              b'1'           b'1'
# 2446                     b'1'          b'0'             b'-1'           b'1'
# 2447                     b'0'          b'0'              b'0'           b'0'
# 2448                     b'0'          b'0'              b'0'           b'1'
# 2449                     b'0'         b'-1'              b'0'           b'0'
# 2450                     b'0'         b'-1'             b'-1'          b'-1'
# 2451                     b'0'          b'0'              b'0'          b'-1'
# 2452                     b'0'          b'0'              b'0'           b'0'
# 2453                     b'0'          b'0'              b'0'           b'1'
# 2454                     b'0'          b'0'             b'-1'          b'-1'
# 2455                     b'0'          b'0'              b'0'           b'1'
#
#      Domain_registeration_length Favicon  ...   popUpWidnow Iframe  \
# 0                           b'0'    b'0'  ...          b'0'   b'0'
# 1                           b'0'    b'0'  ...          b'0'   b'0'
# 2                           b'0'    b'0'  ...          b'0'   b'0'
# 3                           b'1'    b'0'  ...          b'0'   b'0'
# 4                           b'0'    b'0'  ...          b'1'   b'0'
# 5                           b'0'    b'0'  ...          b'0'   b'0'
# 6                          b'-1'    b'1'  ...          b'1'   b'1'
# 7                          b'-1'    b'0'  ...          b'0'   b'0'
# 8                          b'-1'    b'0'  ...          b'0'   b'0'
# 9                           b'1'    b'0'  ...          b'0'   b'0'
# 10                         b'-1'    b'0'  ...          b'0'   b'0'
# 11                          b'0'    b'1'  ...          b'1'   b'1'
# 12                          b'1'    b'1'  ...          b'1'   b'0'
# 13                         b'-1'    b'0'  ...          b'0'   b'0'
# 14                          b'0'    b'0'  ...          b'0'   b'0'
# 15                         b'-1'    b'0'  ...          b'0'   b'0'
# 16                          b'0'    b'0'  ...          b'0'   b'0'
# 17                          b'1'    b'1'  ...          b'1'   b'0'
# 18                          b'1'    b'1'  ...          b'1'   b'0'
# 19                          b'0'    b'0'  ...          b'0'   b'0'
# 20                         b'-1'    b'1'  ...          b'1'   b'0'
# 21                         b'-1'    b'0'  ...          b'0'   b'0'
# 22                          b'0'    b'0'  ...          b'0'   b'0'
# 23                          b'0'    b'0'  ...          b'0'   b'0'
# 24                         b'-1'    b'0'  ...          b'0'   b'0'
# 25                          b'0'    b'0'  ...          b'0'   b'0'
# 26                          b'0'    b'1'  ...          b'1'   b'1'
# 27                         b'-1'    b'0'  ...          b'0'   b'0'
# 28                          b'1'    b'0'  ...          b'0'   b'0'
# 29                          b'1'    b'1'  ...          b'1'   b'0'
# ...                          ...     ...  ...           ...    ...
# 2426                        b'1'    b'1'  ...          b'1'   b'1'
# 2427                        b'0'    b'0'  ...          b'0'   b'0'
# 2428                       b'-1'    b'0'  ...          b'0'   b'0'
# 2429                       b'-1'    b'0'  ...          b'0'   b'0'
# 2430                        b'0'    b'1'  ...          b'1'   b'1'
# 2431                        b'0'    b'0'  ...          b'0'   b'0'
# 2432                        b'1'    b'0'  ...          b'0'   b'0'
# 2433                        b'0'    b'0'  ...          b'0'   b'0'
# 2434                       b'-1'    b'0'  ...          b'0'   b'0'
# 2435                       b'-1'    b'1'  ...          b'1'   b'1'
# 2436                       b'-1'    b'1'  ...          b'1'   b'1'
# 2437                        b'0'    b'1'  ...          b'1'   b'1'
# 2438                       b'-1'    b'0'  ...          b'0'   b'0'
# 2439                        b'1'    b'0'  ...          b'0'   b'0'
# 2440                        b'1'    b'1'  ...          b'1'   b'1'
# 2441                        b'1'    b'0'  ...          b'0'   b'0'
# 2442                        b'1'    b'0'  ...          b'0'   b'0'
# 2443                       b'-1'    b'1'  ...          b'1'   b'1'
# 2444                       b'-1'    b'0'  ...          b'0'   b'0'
# 2445                        b'1'    b'0'  ...          b'0'   b'0'
# 2446                        b'0'    b'0'  ...          b'0'   b'0'
# 2447                        b'1'    b'0'  ...          b'0'   b'0'
# 2448                        b'1'    b'0'  ...          b'0'   b'0'
# 2449                        b'1'    b'1'  ...          b'1'   b'1'
# 2450                        b'0'    b'0'  ...          b'0'   b'0'
# 2451                        b'1'    b'0'  ...          b'0'   b'0'
# 2452                        b'1'    b'0'  ...          b'0'   b'0'
# 2453                        b'0'    b'0'  ...          b'0'   b'0'
# 2454                        b'1'    b'0'  ...          b'0'   b'0'
# 2455                        b'0'    b'0'  ...          b'0'   b'0'
#
#      age_of_domain DNSRecord web_traffic Page_Rank Google_Index  \
# 0            b'-1'      b'1'       b'-1'     b'-1'         b'0'
# 1            b'-1'      b'1'        b'0'     b'-1'         b'0'
# 2             b'0'      b'1'        b'1'     b'-1'         b'0'
# 3            b'-1'      b'1'        b'1'     b'-1'         b'0'
# 4            b'-1'      b'1'        b'0'     b'-1'         b'0'
# 5             b'0'      b'0'        b'1'      b'0'         b'0'
# 6             b'1'      b'1'        b'1'      b'1'         b'0'
# 7             b'1'      b'0'       b'-1'     b'-1'         b'0'
# 8             b'1'      b'0'        b'1'      b'0'         b'0'
# 9             b'0'      b'1'        b'1'     b'-1'         b'0'
# 10           b'-1'      b'1'       b'-1'     b'-1'         b'0'
# 11           b'-1'      b'1'        b'0'     b'-1'         b'0'
# 12           b'-1'      b'1'        b'0'      b'0'         b'0'
# 13            b'1'      b'1'        b'1'     b'-1'         b'1'
# 14           b'-1'      b'1'        b'1'      b'0'         b'0'
# 15            b'0'      b'1'        b'1'     b'-1'         b'0'
# 16            b'1'      b'1'        b'1'      b'0'         b'1'
# 17           b'-1'      b'1'        b'1'     b'-1'         b'0'
# 18            b'1'      b'1'       b'-1'     b'-1'         b'0'
# 19           b'-1'      b'0'        b'1'     b'-1'         b'0'
# 20           b'-1'      b'0'        b'1'      b'0'         b'0'
# 21            b'1'      b'0'        b'1'     b'-1'         b'0'
# 22           b'-1'      b'1'        b'1'     b'-1'         b'0'
# 23           b'-1'      b'1'        b'0'     b'-1'         b'0'
# 24            b'1'      b'0'        b'1'     b'-1'         b'1'
# 25            b'0'      b'0'        b'0'     b'-1'         b'0'
# 26            b'1'      b'1'        b'0'     b'-1'         b'1'
# 27            b'1'      b'1'        b'1'     b'-1'         b'1'
# 28           b'-1'      b'0'        b'1'     b'-1'         b'0'
# 29           b'-1'      b'1'        b'0'     b'-1'         b'0'
# ...            ...       ...         ...       ...          ...
# 2426         b'-1'      b'1'       b'-1'      b'0'         b'0'
# 2427          b'1'      b'1'       b'-1'      b'1'         b'0'
# 2428          b'1'      b'0'        b'1'      b'0'         b'0'
# 2429          b'1'      b'0'        b'1'      b'1'         b'0'
# 2430         b'-1'      b'0'       b'-1'     b'-1'         b'0'
# 2431         b'-1'      b'0'        b'1'     b'-1'         b'0'
# 2432          b'1'      b'1'       b'-1'      b'1'         b'0'
# 2433          b'1'      b'0'        b'1'      b'1'         b'0'
# 2434          b'1'      b'0'       b'-1'     b'-1'         b'0'
# 2435          b'1'      b'1'        b'1'      b'0'         b'0'
# 2436          b'1'      b'1'        b'1'     b'-1'         b'0'
# 2437          b'1'      b'1'       b'-1'     b'-1'         b'0'
# 2438          b'1'      b'0'        b'1'      b'1'         b'0'
# 2439          b'1'      b'0'       b'-1'     b'-1'         b'0'
# 2440          b'1'      b'1'        b'0'     b'-1'         b'0'
# 2441         b'-1'      b'0'        b'0'     b'-1'         b'0'
# 2442         b'-1'      b'1'        b'1'     b'-1'         b'0'
# 2443          b'0'      b'1'        b'1'     b'-1'         b'0'
# 2444          b'1'      b'1'       b'-1'     b'-1'         b'0'
# 2445          b'1'      b'0'        b'1'      b'1'         b'1'
# 2446          b'1'      b'1'        b'1'     b'-1'         b'0'
# 2447          b'0'      b'1'       b'-1'     b'-1'         b'0'
# 2448         b'-1'      b'0'       b'-1'     b'-1'         b'0'
# 2449          b'1'      b'1'        b'1'     b'-1'         b'1'
# 2450         b'-1'      b'0'        b'0'     b'-1'         b'1'
# 2451         b'-1'      b'0'        b'1'      b'0'         b'0'
# 2452          b'0'      b'1'       b'-1'      b'0'         b'0'
# 2453         b'-1'      b'0'        b'1'      b'0'         b'0'
# 2454          b'1'      b'0'       b'-1'     b'-1'         b'0'
# 2455         b'-1'      b'0'        b'1'      b'1'         b'0'
#
#      Links_pointing_to_page Statistical_report Result
# 0                      b'1'               b'1'   b'1'
# 1                      b'1'               b'0'   b'1'
# 2                      b'0'               b'1'   b'1'
# 3                     b'-1'               b'0'   b'1'
# 4                      b'1'               b'0'  b'-1'
# 5                     b'-1'               b'1'  b'-1'
# 6                      b'0'               b'1'  b'-1'
# 7                     b'-1'               b'1'  b'-1'
# 8                      b'0'               b'1'  b'-1'
# 9                      b'1'               b'1'   b'1'
# 10                     b'1'               b'0'   b'1'
# 11                     b'0'               b'0'   b'1'
# 12                     b'0'               b'0'   b'1'
# 13                     b'1'               b'1'  b'-1'
# 14                     b'0'               b'0'  b'-1'
# 15                     b'0'               b'0'  b'-1'
# 16                    b'-1'               b'0'  b'-1'
# 17                    b'-1'               b'1'   b'1'
# 18                     b'0'               b'1'   b'1'
# 19                     b'1'               b'1'   b'1'
# 20                     b'0'               b'0'  b'-1'
# 21                     b'1'               b'1'  b'-1'
# 22                     b'0'               b'0'   b'1'
# 23                     b'0'               b'0'   b'1'
# 24                    b'-1'               b'1'  b'-1'
# 25                     b'0'               b'0'   b'1'
# 26                     b'0'               b'0'  b'-1'
# 27                     b'0'               b'1'  b'-1'
# 28                     b'0'               b'0'   b'1'
# 29                     b'0'               b'1'   b'1'
# ...                     ...                ...    ...
# 2426                   b'1'               b'1'   b'1'
# 2427                   b'1'               b'0'  b'-1'
# 2428                   b'0'               b'0'  b'-1'
# 2429                   b'0'               b'0'  b'-1'
# 2430                   b'0'               b'1'   b'1'
# 2431                   b'0'               b'0'   b'1'
# 2432                   b'1'               b'0'  b'-1'
# 2433                   b'0'               b'0'  b'-1'
# 2434                   b'0'               b'0'   b'1'
# 2435                   b'1'               b'1'  b'-1'
# 2436                   b'1'               b'1'  b'-1'
# 2437                   b'1'               b'1'   b'1'
# 2438                   b'0'               b'0'  b'-1'
# 2439                   b'0'               b'0'   b'1'
# 2440                   b'1'               b'1'   b'1'
# 2441                   b'0'               b'0'   b'1'
# 2442                   b'1'               b'0'   b'1'
# 2443                   b'1'               b'1'   b'1'
# 2444                   b'1'               b'0'  b'-1'
# 2445                   b'0'               b'0'  b'-1'
# 2446                   b'1'               b'0'  b'-1'
# 2447                   b'1'               b'0'   b'1'
# 2448                   b'0'               b'0'  b'-1'
# 2449                   b'1'               b'1'   b'1'
# 2450                   b'0'               b'0'   b'1'
# 2451                   b'0'               b'0'   b'1'
# 2452                   b'1'               b'0'   b'1'
# 2453                   b'0'               b'0'  b'-1'
# 2454                   b'0'               b'0'   b'1'
# 2455                   b'0'               b'0'  b'-1'
#
# [2456 rows x 31 columns]>

# %%
for i in dt.columns:
    dt[i]=dt[i].astype(dtype='i')

# %%
x=dt.drop('Result',axis=1)
y=dt['Result']
from sklearn.model_selection import train_test_split
x_tr,x_ts,y_tr,y_ts=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB
algo1=GaussianNB()
algo1.fit(x_tr,y_tr)
algo1.score(x_ts,y_ts)
# Out:
# 0.9105691056910569

# %%
from sklearn.linear_model import LogisticRegression
algo2=LogisticRegression()
algo2.fit(x_tr,y_tr)
algo2.score(x_ts,y_ts)
# Out:
# 0.9390243902439024

# %%
from sklearn.svm import SVC
algo4=SVC()
algo4.fit(x_tr,y_tr)
algo4.score(x_ts,y_ts)
# Out:
# 0.9491869918699187

# %%
from sklearn.tree import DecisionTreeClassifier
algo3=DecisionTreeClassifier()
algo3.fit(x_tr,y_tr)
algo3.score(x_ts,y_ts)
# Out:
# 0.9695121951219512

# %%
from sklearn.ensemble import RandomForestClassifier
algo5=RandomForestClassifier()
algo5.fit(x_tr,y_tr)
algo5.score(x_ts,y_ts)
# Out:
# 0.975609756097561
